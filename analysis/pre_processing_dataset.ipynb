# %%
import utils as ut

from importlib import reload

reload(ut)

# Cria os diretórios necessários
ut.setup()

# %%
import matplotlib.pyplot as plt

_, axes = plt.subplots(1, 2)


for dir, ax in zip(["training", "testing"], axes):
    df = ut.process_images(dir)
    ut.pie(df, ax, f"{dir.title()} Label Distribution")
# Out:
# ../archive/training
# ../archive/testing
